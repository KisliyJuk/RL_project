# %%
# !pip install swig # needed to build Box2D in the pip install
# !pip install box2d-py
# !pip install gym[box2d]
# Out:
# Collecting swig
#   Downloading swig-4.1.1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 12.8 MB/s eta 0:00:00
# Installing collected packages: swig
# Successfully installed swig-4.1.1
# Collecting box2d-py
#   Downloading box2d-py-2.3.8.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.5/374.5 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.8-cp310-cp310-linux_x86_64.whl size=2373071 sha256=bff6d98eddf3b2ba68de20b55e32343f1cc937d45acdc6ecaabab14dcf925672
#   Stored in directory: /root/.cache/pip/wheels/47/01/d2/6a780da77ccb98b1d2facdd520a8d10838a03b590f6f8d50c0
# Successfully built box2d-py
# Installing collected packages: box2d-py
# Successfully installed box2d-py-2.3.8
# Requirement already satisfied: gym[box2d] in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym[box2d]) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym[box2d]) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym[box2d]) (0.0.8)
# Collecting box2d-py==2.3.5 (from gym[box2d])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 7.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pygame==2.1.0 (from gym[box2d])
#   Downloading pygame-2.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 57.7 MB/s eta 0:00:00
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.10/dist-packages (from gym[box2d]) (4.1.1)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp310-cp310-linux_x86_64.whl size=2373076 sha256=4b36551a67e2a293decd4708d7dbb8ed50fad1ce77bd9e2e498fa9a862b123f8
#   Stored in directory: /root/.cache/pip/wheels/db/8f/6a/eaaadf056fba10a98d986f6dce954e6201ba3126926fc5ad9e
# Successfully built box2d-py
# Installing collected packages: box2d-py, pygame
#   Attempting uninstall: box2d-py
#     Found existing installation: box2d-py 2.3.8
#     Uninstalling box2d-py-2.3.8:
#       Successfully uninstalled box2d-py-2.3.8
#   Attempting uninstall: pygame
#     Found existing installation: pygame 2.5.2
#     Uninstalling pygame-2.5.2:
#       Successfully uninstalled pygame-2.5.2
# Successfully installed box2d-py-2.3.5 pygame-2.1.0

# %%
import gym
import random
from create_agent import Agent
from utils import plot_learning_curve
import numpy as np

# %%
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np


class DeepQNetwork(nn.Module):
    def __init__(self, lr, input_dims, fc1_dims, fc2_dims,
                 n_actions):
        super(DeepQNetwork, self).__init__()
        self.input_dims = input_dims
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.n_actions = n_actions
        self.fc1 = nn.Linear(*self.input_dims, self.fc1_dims)
        self.fc2 = nn.Linear(self.fc1_dims, self.fc2_dims)
        self.fc3 = nn.Linear(self.fc2_dims, self.n_actions)

        self.optimizer = optim.Adam(self.parameters(), lr=lr)
        self.loss = nn.MSELoss()
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.to(self.device)

    def forward(self, state):
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        actions = self.fc3(x)

        return actions


class Agent:
    def __init__(self, gamma, epsilon, lr, input_dims, batch_size, n_actions,
                 max_mem_size=1000000, eps_end=0.05, eps_dec=5e-4):
        self.gamma = gamma
        self.epsilon = epsilon
        self.eps_min = eps_end
        self.eps_dec = eps_dec
        self.lr = lr
        self.action_space = [i for i in range(n_actions)]
        self.mem_size = max_mem_size
        self.batch_size = batch_size
        self.mem_cntr = 0
        self.iter_cntr = 0
        self.replace_target = 100

        self.Q_eval = DeepQNetwork(lr, n_actions=n_actions,
                                   input_dims=input_dims,
                                   fc1_dims=256, fc2_dims=256)

        self.state_memory = np.zeros((self.mem_size-1, *input_dims),
                                     dtype=np.float32)
        # print(self.state_memory.shape)
        self.new_state_memory = np.zeros((self.mem_size, *input_dims),
                                         dtype=np.float32)
        self.action_memory = np.zeros(self.mem_size, dtype=np.int32)
        self.reward_memory = np.zeros(self.mem_size, dtype=np.float32)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.bool)

    def store_transition(self, state, action, reward, state_, terminal):
        index = self.mem_cntr % self.mem_size
        # print(state)
        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.reward_memory[index] = reward
        self.action_memory[index] = action
        self.terminal_memory[index] = terminal

        self.mem_cntr += 1

    def choose_action(self, observation):
        if np.random.random() > self.epsilon:
            state = T.tensor([observation]).to(self.Q_eval.device)
            actions = self.Q_eval.forward(T.tensor(state))
            action = T.argmax(actions).item()
        else:
            action = np.random.choice(self.action_space)

        return action

    def learn(self):
        if self.mem_cntr < self.batch_size:
            return

        self.Q_eval.optimizer.zero_grad()

        max_mem = min(self.mem_cntr, self.mem_size)

        batch = np.random.choice(max_mem, self.batch_size, replace=False)
        batch_index = np.arange(self.batch_size, dtype=np.int32)

        state_batch = T.tensor(self.state_memory[batch]).to(self.Q_eval.device)
        new_state_batch = T.tensor(
                self.new_state_memory[batch]).to(self.Q_eval.device)
        action_batch = self.action_memory[batch]
        reward_batch = T.tensor(
                self.reward_memory[batch]).to(self.Q_eval.device)
        terminal_batch = T.tensor(
                self.terminal_memory[batch]).to(self.Q_eval.device)

        q_eval = self.Q_eval.forward(state_batch)[batch_index, action_batch]
        q_next = self.Q_eval.forward(new_state_batch)
        q_next[terminal_batch] = 0.0

        q_target = reward_batch + self.gamma*T.max(q_next, dim=1)[0]

        loss = self.Q_eval.loss(q_target, q_eval).to(self.Q_eval.device)
        loss.backward()
        self.Q_eval.optimizer.step()

        self.iter_cntr += 1
        self.epsilon = self.epsilon - self.eps_dec \
            if self.epsilon > self.eps_min else self.eps_min
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
env = gym.make('Acrobot-v1')
agent = Agent(gamma=0.99, epsilon=1.0, batch_size=1024, n_actions=3, eps_end=0.001,
              input_dims=[6], lr=0.0001)
scores, eps_history = [], []
n_games = 500

for i in range(n_games):
    score = 0
    done = False
    observation = env.reset()
    while not done:
        action = agent.choose_action(observation)
        observation_, reward, done, info = env.step(action)
        score += reward
        agent.store_transition(observation, action, reward,
                                observation_, done)
        agent.learn()
        observation = observation_
    scores.append(score)
    eps_history.append(agent.epsilon)

    avg_score = np.mean(scores[-100:])

    print('episode ', i, 'score %.2f' % score,
            'average score %.2f' % avg_score,
            'epsilon %.2f' % agent.epsilon)
x = [i+1 for i in range(n_games)]
filename = 'Acrobot.png'
plot_learning_curve(x, scores, eps_history, filename)
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# <ipython-input-3-f79367161b47>:59: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self.terminal_memory = np.zeros(self.mem_size, dtype=np.bool)
# episode  0 score -500.00 average score -500.00 epsilon 1.00
# episode  1 score -500.00 average score -500.00 epsilon 1.00
# <ipython-input-3-f79367161b47>:74: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:261.)
#   state = T.tensor([observation]).to(self.Q_eval.device)
# <ipython-input-3-f79367161b47>:75: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   actions = self.Q_eval.forward(T.tensor(state))
# episode  2 score -301.00 average score -433.67 epsilon 0.86
# episode  3 score -309.00 average score -402.50 epsilon 0.71
# episode  4 score -341.00 average score -390.20 epsilon 0.53
# episode  5 score -482.00 average score -405.50 epsilon 0.29
# episode  6 score -247.00 average score -382.86 epsilon 0.17
# episode  7 score -157.00 average score -354.62 epsilon 0.09
# episode  8 score -102.00 average score -326.56 epsilon 0.04
# episode  9 score -112.00 average score -305.10 epsilon 0.00
# episode  10 score -120.00 average score -288.27 epsilon 0.00
# episode  11 score -132.00 average score -275.25 epsilon 0.00
# episode  12 score -173.00 average score -267.38 epsilon 0.00
# episode  13 score -133.00 average score -257.79 epsilon 0.00
# episode  14 score -357.00 average score -264.40 epsilon 0.00
# episode  15 score -114.00 average score -255.00 epsilon 0.00
# episode  16 score -144.00 average score -248.47 epsilon 0.00
# episode  17 score -95.00 average score -239.94 epsilon 0.00
# episode  18 score -103.00 average score -232.74 epsilon 0.00
# episode  19 score -105.00 average score -226.35 epsilon 0.00
# episode  20 score -184.00 average score -224.33 epsilon 0.00
# episode  21 score -151.00 average score -221.00 epsilon 0.00
# episode  22 score -92.00 average score -215.39 epsilon 0.00
# episode  23 score -116.00 average score -211.25 epsilon 0.00
# episode  24 score -119.00 average score -207.56 epsilon 0.00
# episode  25 score -93.00 average score -203.15 epsilon 0.00
# episode  26 score -127.00 average score -200.33 epsilon 0.00
# episode  27 score -500.00 average score -211.04 epsilon 0.00
# episode  28 score -500.00 average score -221.00 epsilon 0.00
# episode  29 score -500.00 average score -230.30 epsilon 0.00
# episode  30 score -500.00 average score -239.00 epsilon 0.00
# episode  31 score -413.00 average score -244.44 epsilon 0.00
# episode  32 score -500.00 average score -252.18 epsilon 0.00
# episode  33 score -500.00 average score -259.47 epsilon 0.00
# episode  34 score -135.00 average score -255.91 epsilon 0.00
# episode  35 score -132.00 average score -252.47 epsilon 0.00
# episode  36 score -101.00 average score -248.38 epsilon 0.00
# episode  37 score -133.00 average score -245.34 epsilon 0.00
# episode  38 score -87.00 average score -241.28 epsilon 0.00
# episode  39 score -119.00 average score -238.22 epsilon 0.00
# episode  40 score -96.00 average score -234.76 epsilon 0.00
# episode  41 score -134.00 average score -232.36 epsilon 0.00
# episode  42 score -85.00 average score -228.93 epsilon 0.00
# episode  43 score -128.00 average score -226.64 epsilon 0.00
# episode  44 score -182.00 average score -225.64 epsilon 0.00
# episode  45 score -95.00 average score -222.80 epsilon 0.00
# episode  46 score -129.00 average score -220.81 epsilon 0.00
# episode  47 score -98.00 average score -218.25 epsilon 0.00
# episode  48 score -281.00 average score -219.53 epsilon 0.00
# episode  49 score -85.00 average score -216.84 epsilon 0.00
# episode  50 score -86.00 average score -214.27 epsilon 0.00
# episode  51 score -87.00 average score -211.83 epsilon 0.00
# episode  52 score -86.00 average score -209.45 epsilon 0.00
# episode  53 score -85.00 average score -207.15 epsilon 0.00
# episode  54 score -113.00 average score -205.44 epsilon 0.00
# episode  55 score -84.00 average score -203.27 epsilon 0.00
# episode  56 score -142.00 average score -202.19 epsilon 0.00
# episode  57 score -108.00 average score -200.57 epsilon 0.00
# episode  58 score -104.00 average score -198.93 epsilon 0.00
# episode  59 score -88.00 average score -197.08 epsilon 0.00
# episode  60 score -90.00 average score -195.33 epsilon 0.00
# episode  61 score -76.00 average score -193.40 epsilon 0.00
# episode  62 score -89.00 average score -191.75 epsilon 0.00
# episode  63 score -137.00 average score -190.89 epsilon 0.00
# episode  64 score -119.00 average score -189.78 epsilon 0.00
# episode  65 score -77.00 average score -188.08 epsilon 0.00
# episode  66 score -76.00 average score -186.40 epsilon 0.00
# episode  67 score -91.00 average score -185.00 epsilon 0.00
# episode  68 score -255.00 average score -186.01 epsilon 0.00
# episode  69 score -247.00 average score -186.89 epsilon 0.00
# episode  70 score -85.00 average score -185.45 epsilon 0.00
# episode  71 score -106.00 average score -184.35 epsilon 0.00
# episode  72 score -101.00 average score -183.21 epsilon 0.00
# episode  73 score -95.00 average score -182.01 epsilon 0.00
# episode  74 score -72.00 average score -180.55 epsilon 0.00
# episode  75 score -88.00 average score -179.33 epsilon 0.00
# episode  76 score -88.00 average score -178.14 epsilon 0.00
# episode  77 score -116.00 average score -177.35 epsilon 0.00
# episode  78 score -63.00 average score -175.90 epsilon 0.00
# episode  79 score -70.00 average score -174.57 epsilon 0.00
# episode  80 score -85.00 average score -173.47 epsilon 0.00
# episode  81 score -79.00 average score -172.32 epsilon 0.00
# episode  82 score -76.00 average score -171.16 epsilon 0.00
# episode  83 score -76.00 average score -170.02 epsilon 0.00
# episode  84 score -62.00 average score -168.75 epsilon 0.00
# episode  85 score -92.00 average score -167.86 epsilon 0.00
# episode  86 score -69.00 average score -166.72 epsilon 0.00
# episode  87 score -76.00 average score -165.69 epsilon 0.00
# episode  88 score -76.00 average score -164.69 epsilon 0.00
# episode  89 score -90.00 average score -163.86 epsilon 0.00
# episode  90 score -75.00 average score -162.88 epsilon 0.00
# episode  91 score -70.00 average score -161.87 epsilon 0.00
# episode  92 score -500.00 average score -165.51 epsilon 0.00
# episode  93 score -75.00 average score -164.54 epsilon 0.00
# episode  94 score -85.00 average score -163.71 epsilon 0.00
# episode  95 score -84.00 average score -162.88 epsilon 0.00
# episode  96 score -75.00 average score -161.97 epsilon 0.00
# episode  97 score -75.00 average score -161.08 epsilon 0.00
# episode  98 score -86.00 average score -160.32 epsilon 0.00
# episode  99 score -76.00 average score -159.48 epsilon 0.00
# episode  100 score -74.00 average score -155.22 epsilon 0.00
# episode  101 score -85.00 average score -151.07 epsilon 0.00
# episode  102 score -92.00 average score -148.98 epsilon 0.00
# episode  103 score -88.00 average score -146.77 epsilon 0.00
# episode  104 score -81.00 average score -144.17 epsilon 0.00
# episode  105 score -82.00 average score -140.17 epsilon 0.00
# episode  106 score -96.00 average score -138.66 epsilon 0.00
# episode  107 score -75.00 average score -137.84 epsilon 0.00
# episode  108 score -87.00 average score -137.69 epsilon 0.00
# episode  109 score -75.00 average score -137.32 epsilon 0.00
# episode  110 score -86.00 average score -136.98 epsilon 0.00
# episode  111 score -95.00 average score -136.61 epsilon 0.00
# episode  112 score -101.00 average score -135.89 epsilon 0.00
# episode  113 score -79.00 average score -135.35 epsilon 0.00
# episode  114 score -150.00 average score -133.28 epsilon 0.00
# episode  115 score -94.00 average score -133.08 epsilon 0.00
# episode  116 score -75.00 average score -132.39 epsilon 0.00
# episode  117 score -93.00 average score -132.37 epsilon 0.00
# episode  118 score -62.00 average score -131.96 epsilon 0.00
# episode  119 score -100.00 average score -131.91 epsilon 0.00
# episode  120 score -83.00 average score -130.90 epsilon 0.00
# episode  121 score -71.00 average score -130.10 epsilon 0.00
# episode  122 score -126.00 average score -130.44 epsilon 0.00
# episode  123 score -89.00 average score -130.17 epsilon 0.00
# episode  124 score -62.00 average score -129.60 epsilon 0.00
# episode  125 score -85.00 average score -129.52 epsilon 0.00
# episode  126 score -116.00 average score -129.41 epsilon 0.00
# episode  127 score -117.00 average score -125.58 epsilon 0.00
# episode  128 score -99.00 average score -121.57 epsilon 0.00
# episode  129 score -96.00 average score -117.53 epsilon 0.00
# episode  130 score -71.00 average score -113.24 epsilon 0.00
# episode  131 score -153.00 average score -110.64 epsilon 0.00
# episode  132 score -94.00 average score -106.58 epsilon 0.00
# episode  133 score -92.00 average score -102.50 epsilon 0.00
# episode  134 score -81.00 average score -101.96 epsilon 0.00
# episode  135 score -93.00 average score -101.57 epsilon 0.00
# episode  136 score -89.00 average score -101.45 epsilon 0.00
# episode  137 score -224.00 average score -102.36 epsilon 0.00
# episode  138 score -85.00 average score -102.34 epsilon 0.00
# episode  139 score -104.00 average score -102.19 epsilon 0.00
# episode  140 score -119.00 average score -102.42 epsilon 0.00
# episode  141 score -83.00 average score -101.91 epsilon 0.00
# episode  142 score -112.00 average score -102.18 epsilon 0.00
# episode  143 score -418.00 average score -105.08 epsilon 0.00
# episode  144 score -114.00 average score -104.40 epsilon 0.00
# episode  145 score -86.00 average score -104.31 epsilon 0.00
# episode  146 score -160.00 average score -104.62 epsilon 0.00
# episode  147 score -63.00 average score -104.27 epsilon 0.00
# episode  148 score -125.00 average score -102.71 epsilon 0.00
# episode  149 score -92.00 average score -102.78 epsilon 0.00
# episode  150 score -78.00 average score -102.70 epsilon 0.00
# episode  151 score -108.00 average score -102.91 epsilon 0.00
# episode  152 score -95.00 average score -103.00 epsilon 0.00
# episode  153 score -89.00 average score -103.04 epsilon 0.00
# episode  154 score -119.00 average score -103.10 epsilon 0.00
# episode  155 score -119.00 average score -103.45 epsilon 0.00
# episode  156 score -120.00 average score -103.23 epsilon 0.00
# episode  157 score -148.00 average score -103.63 epsilon 0.00
# episode  158 score -97.00 average score -103.56 epsilon 0.00
# episode  159 score -120.00 average score -103.88 epsilon 0.00
# episode  160 score -132.00 average score -104.30 epsilon 0.00
# episode  161 score -95.00 average score -104.49 epsilon 0.00
# episode  162 score -96.00 average score -104.56 epsilon 0.00
# episode  163 score -80.00 average score -103.99 epsilon 0.00
# episode  164 score -79.00 average score -103.59 epsilon 0.00
# episode  165 score -77.00 average score -103.59 epsilon 0.00
# episode  166 score -150.00 average score -104.33 epsilon 0.00
# episode  167 score -128.00 average score -104.70 epsilon 0.00
# episode  168 score -86.00 average score -103.01 epsilon 0.00
# episode  169 score -97.00 average score -101.51 epsilon 0.00
# episode  170 score -154.00 average score -102.20 epsilon 0.00
# episode  171 score -126.00 average score -102.40 epsilon 0.00
# episode  172 score -64.00 average score -102.03 epsilon 0.00
# episode  173 score -63.00 average score -101.71 epsilon 0.00
# episode  174 score -95.00 average score -101.94 epsilon 0.00
# episode  175 score -120.00 average score -102.26 epsilon 0.00
# episode  176 score -124.00 average score -102.62 epsilon 0.00
# episode  177 score -126.00 average score -102.72 epsilon 0.00
# episode  178 score -128.00 average score -103.37 epsilon 0.00
# episode  179 score -96.00 average score -103.63 epsilon 0.00
# episode  180 score -105.00 average score -103.83 epsilon 0.00
# episode  181 score -115.00 average score -104.19 epsilon 0.00
# episode  182 score -93.00 average score -104.36 epsilon 0.00
# episode  183 score -92.00 average score -104.52 epsilon 0.00
# episode  184 score -151.00 average score -105.41 epsilon 0.00
# episode  185 score -87.00 average score -105.36 epsilon 0.00
# episode  186 score -86.00 average score -105.53 epsilon 0.00
# episode  187 score -85.00 average score -105.62 epsilon 0.00
# episode  188 score -100.00 average score -105.86 epsilon 0.00
# episode  189 score -111.00 average score -106.07 epsilon 0.00
# episode  190 score -103.00 average score -106.35 epsilon 0.00
# episode  191 score -120.00 average score -106.85 epsilon 0.00
# episode  192 score -125.00 average score -103.10 epsilon 0.00
# episode  193 score -193.00 average score -104.28 epsilon 0.00
# episode  194 score -131.00 average score -104.74 epsilon 0.00
# episode  195 score -117.00 average score -105.07 epsilon 0.00
# episode  196 score -132.00 average score -105.64 epsilon 0.00
# episode  197 score -64.00 average score -105.53 epsilon 0.00
# episode  198 score -241.00 average score -107.08 epsilon 0.00
# episode  199 score -129.00 average score -107.61 epsilon 0.00
# episode  200 score -87.00 average score -107.74 epsilon 0.00
# episode  201 score -183.00 average score -108.72 epsilon 0.00
# episode  202 score -116.00 average score -108.96 epsilon 0.00
# episode  203 score -178.00 average score -109.86 epsilon 0.00
# episode  204 score -100.00 average score -110.05 epsilon 0.00
# episode  205 score -162.00 average score -110.85 epsilon 0.00
# episode  206 score -129.00 average score -111.18 epsilon 0.00
# episode  207 score -288.00 average score -113.31 epsilon 0.00
# episode  208 score -78.00 average score -113.22 epsilon 0.00
# episode  209 score -138.00 average score -113.85 epsilon 0.00
# episode  210 score -127.00 average score -114.26 epsilon 0.00
# episode  211 score -113.00 average score -114.44 epsilon 0.00
# episode  212 score -278.00 average score -116.21 epsilon 0.00
# episode  213 score -158.00 average score -117.00 epsilon 0.00
# episode  214 score -109.00 average score -116.59 epsilon 0.00
# episode  215 score -333.00 average score -118.98 epsilon 0.00
# episode  216 score -131.00 average score -119.54 epsilon 0.00
# episode  217 score -136.00 average score -119.97 epsilon 0.00
# episode  218 score -197.00 average score -121.32 epsilon 0.00
# episode  219 score -301.00 average score -123.33 epsilon 0.00
# episode  220 score -228.00 average score -124.78 epsilon 0.00
# episode  221 score -200.00 average score -126.07 epsilon 0.00
# episode  222 score -480.00 average score -129.61 epsilon 0.00
# episode  223 score -275.00 average score -131.47 epsilon 0.00
# episode  224 score -175.00 average score -132.60 epsilon 0.00
# episode  225 score -148.00 average score -133.23 epsilon 0.00
# episode  226 score -107.00 average score -133.14 epsilon 0.00
# episode  227 score -198.00 average score -133.95 epsilon 0.00
# episode  228 score -193.00 average score -134.89 epsilon 0.00
# episode  229 score -500.00 average score -138.93 epsilon 0.00
# episode  230 score -226.00 average score -140.48 epsilon 0.00
# episode  231 score -161.00 average score -140.56 epsilon 0.00
# episode  232 score -249.00 average score -142.11 epsilon 0.00
# episode  233 score -212.00 average score -143.31 epsilon 0.00
# episode  234 score -169.00 average score -144.19 epsilon 0.00
# episode  235 score -99.00 average score -144.25 epsilon 0.00
# episode  236 score -143.00 average score -144.79 epsilon 0.00
# episode  237 score -93.00 average score -143.48 epsilon 0.00
# episode  238 score -115.00 average score -143.78 epsilon 0.00
# episode  239 score -88.00 average score -143.62 epsilon 0.00
# episode  240 score -100.00 average score -143.43 epsilon 0.00
# episode  241 score -106.00 average score -143.66 epsilon 0.00
# episode  242 score -125.00 average score -143.79 epsilon 0.00
# episode  243 score -139.00 average score -141.00 epsilon 0.00
# episode  244 score -139.00 average score -141.25 epsilon 0.00
# episode  245 score -101.00 average score -141.40 epsilon 0.00
# episode  246 score -144.00 average score -141.24 epsilon 0.00
# episode  247 score -142.00 average score -142.03 epsilon 0.00
# episode  248 score -154.00 average score -142.32 epsilon 0.00
# episode  249 score -118.00 average score -142.58 epsilon 0.00
# episode  250 score -85.00 average score -142.65 epsilon 0.00
# episode  251 score -95.00 average score -142.52 epsilon 0.00
# episode  252 score -126.00 average score -142.83 epsilon 0.00
# episode  253 score -157.00 average score -143.51 epsilon 0.00
# episode  254 score -99.00 average score -143.31 epsilon 0.00
# episode  255 score -128.00 average score -143.40 epsilon 0.00
# episode  256 score -71.00 average score -142.91 epsilon 0.00
# episode  257 score -105.00 average score -142.48 epsilon 0.00
# episode  258 score -104.00 average score -142.55 epsilon 0.00
# episode  259 score -122.00 average score -142.57 epsilon 0.00
# episode  260 score -119.00 average score -142.44 epsilon 0.00
# episode  261 score -98.00 average score -142.47 epsilon 0.00
# episode  262 score -123.00 average score -142.74 epsilon 0.00
# episode  263 score -111.00 average score -143.05 epsilon 0.00
# episode  264 score -96.00 average score -143.22 epsilon 0.00
# episode  265 score -142.00 average score -143.87 epsilon 0.00
# episode  266 score -110.00 average score -143.47 epsilon 0.00
# episode  267 score -83.00 average score -143.02 epsilon 0.00
# episode  268 score -87.00 average score -143.03 epsilon 0.00
# episode  269 score -105.00 average score -143.11 epsilon 0.00
# episode  270 score -128.00 average score -142.85 epsilon 0.00
# episode  271 score -91.00 average score -142.50 epsilon 0.00
# episode  272 score -63.00 average score -142.49 epsilon 0.00
# episode  273 score -106.00 average score -142.92 epsilon 0.00
# episode  274 score -93.00 average score -142.90 epsilon 0.00
# episode  275 score -123.00 average score -142.93 epsilon 0.00
# episode  276 score -115.00 average score -142.84 epsilon 0.00
# episode  277 score -106.00 average score -142.64 epsilon 0.00
# episode  278 score -77.00 average score -142.13 epsilon 0.00
# episode  279 score -88.00 average score -142.05 epsilon 0.00
# episode  280 score -109.00 average score -142.09 epsilon 0.00
# episode  281 score -104.00 average score -141.98 epsilon 0.00
# episode  282 score -124.00 average score -142.29 epsilon 0.00
# episode  283 score -83.00 average score -142.20 epsilon 0.00
# episode  284 score -122.00 average score -141.91 epsilon 0.00
# episode  285 score -124.00 average score -142.28 epsilon 0.00
# episode  286 score -62.00 average score -142.04 epsilon 0.00
# episode  287 score -194.00 average score -143.13 epsilon 0.00
# episode  288 score -87.00 average score -143.00 epsilon 0.00
# episode  289 score -62.00 average score -142.51 epsilon 0.00
# episode  290 score -70.00 average score -142.18 epsilon 0.00
# episode  291 score -62.00 average score -141.60 epsilon 0.00
# episode  292 score -81.00 average score -141.16 epsilon 0.00
# episode  293 score -97.00 average score -140.20 epsilon 0.00
# episode  294 score -75.00 average score -139.64 epsilon 0.00
# episode  295 score -70.00 average score -139.17 epsilon 0.00
# episode  296 score -84.00 average score -138.69 epsilon 0.00
# episode  297 score -76.00 average score -138.81 epsilon 0.00
# episode  298 score -71.00 average score -137.11 epsilon 0.00
# episode  299 score -87.00 average score -136.69 epsilon 0.00
# episode  300 score -78.00 average score -136.60 epsilon 0.00
# episode  301 score -95.00 average score -135.72 epsilon 0.00
# episode  302 score -70.00 average score -135.26 epsilon 0.00
# episode  303 score -86.00 average score -134.34 epsilon 0.00
# episode  304 score -62.00 average score -133.96 epsilon 0.00
# episode  305 score -124.00 average score -133.58 epsilon 0.00
# episode  306 score -117.00 average score -133.46 epsilon 0.00
# episode  307 score -109.00 average score -131.67 epsilon 0.00
# episode  308 score -79.00 average score -131.68 epsilon 0.00
# episode  309 score -76.00 average score -131.06 epsilon 0.00
# episode  310 score -113.00 average score -130.92 epsilon 0.00
# episode  311 score -68.00 average score -130.47 epsilon 0.00
# episode  312 score -76.00 average score -128.45 epsilon 0.00
# episode  313 score -72.00 average score -127.59 epsilon 0.00
# episode  314 score -70.00 average score -127.20 epsilon 0.00
# episode  315 score -104.00 average score -124.91 epsilon 0.00
# episode  316 score -75.00 average score -124.35 epsilon 0.00
# episode  317 score -107.00 average score -124.06 epsilon 0.00
# episode  318 score -76.00 average score -122.85 epsilon 0.00
# episode  319 score -92.00 average score -120.76 epsilon 0.00
# episode  320 score -106.00 average score -119.54 epsilon 0.00
# episode  321 score -71.00 average score -118.25 epsilon 0.00
# episode  322 score -76.00 average score -114.21 epsilon 0.00
# episode  323 score -70.00 average score -112.16 epsilon 0.00
# episode  324 score -64.00 average score -111.05 epsilon 0.00
# episode  325 score -76.00 average score -110.33 epsilon 0.00
# episode  326 score -95.00 average score -110.21 epsilon 0.00
# episode  327 score -76.00 average score -108.99 epsilon 0.00
# episode  328 score -85.00 average score -107.91 epsilon 0.00
# episode  329 score -83.00 average score -103.74 epsilon 0.00
# episode  330 score -88.00 average score -102.36 epsilon 0.00
# episode  331 score -89.00 average score -101.64 epsilon 0.00
# episode  332 score -76.00 average score -99.91 epsilon 0.00
# episode  333 score -71.00 average score -98.50 epsilon 0.00
# episode  334 score -76.00 average score -97.57 epsilon 0.00
# episode  335 score -71.00 average score -97.29 epsilon 0.00
# episode  336 score -77.00 average score -96.63 epsilon 0.00
# episode  337 score -87.00 average score -96.57 epsilon 0.00
# episode  338 score -87.00 average score -96.29 epsilon 0.00
# episode  339 score -98.00 average score -96.39 epsilon 0.00
# episode  340 score -79.00 average score -96.18 epsilon 0.00
# episode  341 score -76.00 average score -95.88 epsilon 0.00
# episode  342 score -78.00 average score -95.41 epsilon 0.00
# episode  343 score -77.00 average score -94.79 epsilon 0.00
# episode  344 score -94.00 average score -94.34 epsilon 0.00
# episode  345 score -70.00 average score -94.03 epsilon 0.00
# episode  346 score -82.00 average score -93.41 epsilon 0.00
# episode  347 score -84.00 average score -92.83 epsilon 0.00
# episode  348 score -70.00 average score -91.99 epsilon 0.00
# episode  349 score -86.00 average score -91.67 epsilon 0.00
# episode  350 score -94.00 average score -91.76 epsilon 0.00
# episode  351 score -70.00 average score -91.51 epsilon 0.00
# episode  352 score -79.00 average score -91.04 epsilon 0.00
# episode  353 score -71.00 average score -90.18 epsilon 0.00
# episode  354 score -97.00 average score -90.16 epsilon 0.00
# episode  355 score -78.00 average score -89.66 epsilon 0.00
# episode  356 score -86.00 average score -89.81 epsilon 0.00
# episode  357 score -87.00 average score -89.63 epsilon 0.00
# episode  358 score -98.00 average score -89.57 epsilon 0.00
# episode  359 score -77.00 average score -89.12 epsilon 0.00
# episode  360 score -70.00 average score -88.63 epsilon 0.00
# episode  361 score -104.00 average score -88.69 epsilon 0.00
# episode  362 score -71.00 average score -88.17 epsilon 0.00
# episode  363 score -77.00 average score -87.83 epsilon 0.00
# episode  364 score -96.00 average score -87.83 epsilon 0.00
# episode  365 score -87.00 average score -87.28 epsilon 0.00
# episode  366 score -86.00 average score -87.04 epsilon 0.00
# episode  367 score -78.00 average score -86.99 epsilon 0.00
# episode  368 score -81.00 average score -86.93 epsilon 0.00
# episode  369 score -84.00 average score -86.72 epsilon 0.00
# episode  370 score -89.00 average score -86.33 epsilon 0.00
# episode  371 score -75.00 average score -86.17 epsilon 0.00
# episode  372 score -71.00 average score -86.25 epsilon 0.00
# episode  373 score -107.00 average score -86.26 epsilon 0.00
# episode  374 score -77.00 average score -86.10 epsilon 0.00
# episode  375 score -92.00 average score -85.79 epsilon 0.00
# episode  376 score -91.00 average score -85.55 epsilon 0.00
# episode  377 score -79.00 average score -85.28 epsilon 0.00
# episode  378 score -90.00 average score -85.41 epsilon 0.00
# episode  379 score -95.00 average score -85.48 epsilon 0.00
# episode  380 score -107.00 average score -85.46 epsilon 0.00
# episode  381 score -79.00 average score -85.21 epsilon 0.00
# episode  382 score -71.00 average score -84.68 epsilon 0.00
# episode  383 score -71.00 average score -84.56 epsilon 0.00
# episode  384 score -70.00 average score -84.04 epsilon 0.00
# episode  385 score -80.00 average score -83.60 epsilon 0.00
# episode  386 score -124.00 average score -84.22 epsilon 0.00
# episode  387 score -71.00 average score -82.99 epsilon 0.00
# episode  388 score -80.00 average score -82.92 epsilon 0.00
# episode  389 score -84.00 average score -83.14 epsilon 0.00
# episode  390 score -83.00 average score -83.27 epsilon 0.00
# episode  391 score -102.00 average score -83.67 epsilon 0.00
# episode  392 score -77.00 average score -83.63 epsilon 0.00
# episode  393 score -110.00 average score -83.76 epsilon 0.00
# episode  394 score -80.00 average score -83.81 epsilon 0.00
# episode  395 score -76.00 average score -83.87 epsilon 0.00
# episode  396 score -75.00 average score -83.78 epsilon 0.00
# episode  397 score -98.00 average score -84.00 epsilon 0.00
# episode  398 score -79.00 average score -84.08 epsilon 0.00
# episode  399 score -63.00 average score -83.84 epsilon 0.00
# episode  400 score -87.00 average score -83.93 epsilon 0.00
# episode  401 score -81.00 average score -83.79 epsilon 0.00
# episode  402 score -63.00 average score -83.72 epsilon 0.00
# episode  403 score -78.00 average score -83.64 epsilon 0.00
# episode  404 score -84.00 average score -83.86 epsilon 0.00
# episode  405 score -79.00 average score -83.41 epsilon 0.00
# episode  406 score -84.00 average score -83.08 epsilon 0.00
# episode  407 score -79.00 average score -82.78 epsilon 0.00
# episode  408 score -79.00 average score -82.78 epsilon 0.00
# episode  409 score -108.00 average score -83.10 epsilon 0.00
# episode  410 score -76.00 average score -82.73 epsilon 0.00
# episode  411 score -76.00 average score -82.81 epsilon 0.00
# episode  412 score -77.00 average score -82.82 epsilon 0.00
# episode  413 score -72.00 average score -82.82 epsilon 0.00
# episode  414 score -98.00 average score -83.10 epsilon 0.00
# episode  415 score -157.00 average score -83.63 epsilon 0.00
# episode  416 score -92.00 average score -83.80 epsilon 0.00
# episode  417 score -81.00 average score -83.54 epsilon 0.00
# episode  418 score -86.00 average score -83.64 epsilon 0.00
# episode  419 score -101.00 average score -83.73 epsilon 0.00
# episode  420 score -102.00 average score -83.69 epsilon 0.00
# episode  421 score -66.00 average score -83.64 epsilon 0.00
# episode  422 score -90.00 average score -83.78 epsilon 0.00
# episode  423 score -78.00 average score -83.86 epsilon 0.00
# episode  424 score -77.00 average score -83.99 epsilon 0.00
# episode  425 score -104.00 average score -84.27 epsilon 0.00
# episode  426 score -72.00 average score -84.04 epsilon 0.00
# episode  427 score -96.00 average score -84.24 epsilon 0.00
# episode  428 score -107.00 average score -84.46 epsilon 0.00
# episode  429 score -204.00 average score -85.67 epsilon 0.00
# episode  430 score -96.00 average score -85.75 epsilon 0.00
# episode  431 score -96.00 average score -85.82 epsilon 0.00
# episode  432 score -77.00 average score -85.83 epsilon 0.00
# episode  433 score -108.00 average score -86.20 epsilon 0.00
# episode  434 score -76.00 average score -86.20 epsilon 0.00
# episode  435 score -189.00 average score -87.38 epsilon 0.00
# episode  436 score -63.00 average score -87.24 epsilon 0.00
# episode  437 score -71.00 average score -87.08 epsilon 0.00
# episode  438 score -105.00 average score -87.26 epsilon 0.00
# episode  439 score -62.00 average score -86.90 epsilon 0.00
# episode  440 score -74.00 average score -86.85 epsilon 0.00
# episode  441 score -73.00 average score -86.82 epsilon 0.00
# episode  442 score -95.00 average score -86.99 epsilon 0.00
# episode  443 score -64.00 average score -86.86 epsilon 0.00
# episode  444 score -79.00 average score -86.71 epsilon 0.00
# episode  445 score -77.00 average score -86.78 epsilon 0.00
# episode  446 score -90.00 average score -86.86 epsilon 0.00
# episode  447 score -99.00 average score -87.01 epsilon 0.00
# episode  448 score -89.00 average score -87.20 epsilon 0.00
# episode  449 score -89.00 average score -87.23 epsilon 0.00
# episode  450 score -101.00 average score -87.30 epsilon 0.00
# episode  451 score -124.00 average score -87.84 epsilon 0.00
# episode  452 score -102.00 average score -88.07 epsilon 0.00
# episode  453 score -187.00 average score -89.23 epsilon 0.00
# episode  454 score -109.00 average score -89.35 epsilon 0.00
# episode  455 score -70.00 average score -89.27 epsilon 0.00
# episode  456 score -94.00 average score -89.35 epsilon 0.00
# episode  457 score -101.00 average score -89.49 epsilon 0.00
# episode  458 score -111.00 average score -89.62 epsilon 0.00
# episode  459 score -88.00 average score -89.73 epsilon 0.00
# episode  460 score -86.00 average score -89.89 epsilon 0.00
# episode  461 score -91.00 average score -89.76 epsilon 0.00
# episode  462 score -82.00 average score -89.87 epsilon 0.00
# episode  463 score -93.00 average score -90.03 epsilon 0.00
# episode  464 score -116.00 average score -90.23 epsilon 0.00
# episode  465 score -70.00 average score -90.06 epsilon 0.00
# episode  466 score -92.00 average score -90.12 epsilon 0.00
# episode  467 score -90.00 average score -90.24 epsilon 0.00
# episode  468 score -73.00 average score -90.16 epsilon 0.00
# episode  469 score -71.00 average score -90.03 epsilon 0.00
# episode  470 score -108.00 average score -90.22 epsilon 0.00
# episode  471 score -111.00 average score -90.58 epsilon 0.00
# episode  472 score -85.00 average score -90.72 epsilon 0.00
# episode  473 score -109.00 average score -90.74 epsilon 0.00
# episode  474 score -109.00 average score -91.06 epsilon 0.00
# episode  475 score -91.00 average score -91.05 epsilon 0.00
# episode  476 score -79.00 average score -90.93 epsilon 0.00
# episode  477 score -80.00 average score -90.94 epsilon 0.00
# episode  478 score -79.00 average score -90.83 epsilon 0.00
# episode  479 score -76.00 average score -90.64 epsilon 0.00
# episode  480 score -92.00 average score -90.49 epsilon 0.00
# episode  481 score -109.00 average score -90.79 epsilon 0.00
# episode  482 score -87.00 average score -90.95 epsilon 0.00
# episode  483 score -79.00 average score -91.03 epsilon 0.00
# episode  484 score -87.00 average score -91.20 epsilon 0.00
# episode  485 score -71.00 average score -91.11 epsilon 0.00
# episode  486 score -77.00 average score -90.64 epsilon 0.00
# episode  487 score -237.00 average score -92.30 epsilon 0.00
# episode  488 score -80.00 average score -92.30 epsilon 0.00
# episode  489 score -99.00 average score -92.45 epsilon 0.00
# episode  490 score -78.00 average score -92.40 epsilon 0.00
# episode  491 score -101.00 average score -92.39 epsilon 0.00
# episode  492 score -79.00 average score -92.41 epsilon 0.00
# episode  493 score -97.00 average score -92.28 epsilon 0.00
# episode  494 score -79.00 average score -92.27 epsilon 0.00
# episode  495 score -63.00 average score -92.14 epsilon 0.00
# episode  496 score -71.00 average score -92.10 epsilon 0.00
# episode  497 score -77.00 average score -91.89 epsilon 0.00
# episode  498 score -99.00 average score -92.09 epsilon 0.00
# episode  499 score -123.00 average score -92.69 epsilon 0.00

# %%
from matplotlib import animation
import matplotlib.pyplot as plt

def display_frames_as_gif(frames):
    patch = plt.imshow(frames[0])
    plt.axis('off')
    def animate(i):
        patch.set_data(frames[i])

    anim = animation.FuncAnimation(plt.gcf(), animate, frames = len(frames), interval=5)
    anim.save('./Acrobot.gif', writer='imagemagick', fps=30)

# %%
score = 0
done = False
observation = env.reset()
frames = []
while not done:
    frames.append(env.render(mode = 'rgb_array'))
    action = agent.choose_action(observation)
    observation_, reward, done, info = env.step(action)
    score += reward
    observation = observation_
print('Total score : %.2f'%score)
display_frames_as_gif(frames)
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# <ipython-input-3-f79367161b47>:75: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   actions = self.Q_eval.forward(T.tensor(state))
# WARNING:matplotlib.animation:MovieWriter imagemagick unavailable; using Pillow instead.
# Total score : -78.00

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
